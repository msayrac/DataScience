# %% [markdown]
# ## Yapay Zeka
# Dünyanın en ön önemli kaynagı artık petrol değil veridir!
#
# Yapay zeka yeni elektriktir! Andrew NG
#
# Yapay zeka, bir bilgisayarın veya bilgisayar kontrolündeki bir robotun çeşitli faaliyetleri zeki canlılara benzer şekilde yerine getirebilme kabiliyetidir.
#
# Veri bilimi veriden faydalı bilgiler cıkarma sürecidir.
#
# ## İş problemlerine çözüm oluşturma
#
# Algoritmaya veri bulmak yerine bir probleme veri algoritma bulmak önemlidir.
#
# ## Bazı Başlangıç Problemi

# %% [markdown]
# ## Veri Bilimi İçin İstatistik
