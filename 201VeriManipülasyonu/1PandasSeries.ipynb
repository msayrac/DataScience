# %% [markdown]
# # Pandas
# ## veri bilimi için vb kullanılır. Panel Data kısaltılmısı
# ## numpy genişletilmiş halidir
# ## farklı veri tipleri ile calısır
# ## Veri manipülasyonu ve veri analizi için yazılmıs acık kaynak kodlu bir Python kütüphanesidir
# ## Ekonometrik ve finansal çalışmalar için doğmuştur
# ## 2008 yılında yapılıyor. Mevcut Python yetersiz germesi sonucu Pandas kütüphanesini oluşturuyor.
# ## Finans ihtiyacından doğuyor. Zaman serileri demek istatisitk demek, veri ile iç içe olmak demek.
# ## Dataframe  üzerinde calısmamızı saglar.
# ## Pandas bir çok veri tipini okuma ve yazma imkanı sağlar.

# %% [markdown]
# # Pandas serisi oluşturmak

# %%
import pandas as pd

# %%
seri = pd.Series([1,2,3,4,5])
# ilk sutun index ikinci sutun value. numpydan farkı budur.
seri
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(seri)
# Out:
# pandas.core.series.Series

# %%
seri.axes # 0 dan baslayıp 5 e kadar 1 er  gitmiş
# Out:
# [RangeIndex(start=0, stop=5, step=1)]

# %%
seri.dtype
# Out:
# dtype('int64')

# %%
seri.size
# Out:
# 5

# %%
seri.ndim # boyut
# Out:
# 1

# %%
seri.values # value erisebiliriz
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
seri.values[1]
# Out:
# 2

# %%
seri.head() # seri ilk 5 degerini getirir.
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
seri.head(3) 3 ilk 3 degeri getirir
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
seri.tail(3) # elemanlara sondan bakmak
# Out:
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# index isimlendirmesi
pd.Series([99,22,33,55,94])
# Out:
# 0    99
# 1    22
# 2    33
# 3    55
# 4    94
# dtype: int64

# %%
pd.Series([99,22,33,55,94],index =[1,3,5,7,9])
# Out:
# 1    99
# 3    22
# 5    33
# 7    55
# 9    94
# dtype: int64

# %%
# string degerle isimlendirme
seri =pd.Series([99,22,33,55,94],index =["a","b","c","d","e"])

# %%
seri
# Out:
# a    99
# b    22
# c    33
# d    55
# e    94
# dtype: int64

# %%
seri["a"]
# Out:
# 99

# %%
seri["a":"c"] # slice işlemi
# Out:
# a    99
# b    22
# c    33
# dtype: int64

# %%
# sozluk uzerinden liste olusturmak
sozluk = pd.Series({"reg":10,"log":11,"char":12})

# %%
sozluk
# Out:
# reg     10
# log     11
# char    12
# dtype: int64

# %%
sozluk = {"reg":10,"log":11,"char":12}
sozluk_seri = pd.Series(sozluk)

# %%
sozluk_seri
# Out:
# reg     10
# log     11
# char    12
# dtype: int64

# %%
# iki seriyi birleştirme ve seri olusturma
pd.concat([sozluk_seri,sozluk_seri])
# Out:
# reg     10
# log     11
# char    12
# reg     10
# log     11
# char    12
# dtype: int64

# %%
# Serilerde Eleman işlemleri
import numpy as np
import pandas as pd
a = np.array([1,2,33,44,55,75])
seri = pd.Series(a)
seri
# Out:
# 0     1
# 1     2
# 2    33
# 3    44
# 4    55
# 5    75
# dtype: int32

# %%
seri.values
# Out:
# array([ 1,  2, 33, 44, 55, 75])

# %%
seri[0]
# Out:
# 1

# %%
seri[0:3]
# Out:
# 0     1
# 1     2
# 2    33
# dtype: int32

# %%
seri[0:3].values
# Out:
# array([ 1,  2, 33])

# %%
seri = pd.Series([11,22,33,44],index=["reg","log","cart","rf"])
seri
# Out:
# reg     11
# log     22
# cart    33
# rf      44
# dtype: int64

# %%
seri.index # sadece indexlere erisiriz
# Out:
# Index(['reg', 'log', 'cart', 'rf'], dtype='object')

# %%
seri.keys
# Out:
# <bound method Series.keys of reg     11
# log     22
# cart    33
# rf      44
# dtype: int64>

# %%
seri.values
# Out:
# array([11, 22, 33, 44], dtype=int64)

# %%
list(seri.items()) # key ve value formunda getiririz
# Out:
# [('reg', 11), ('log', 22), ('cart', 33), ('rf', 44)]

# %%
seri.values
# Out:
# array([11, 22, 33, 44], dtype=int64)

# %%
# eleman sorgulama
"reg" in seri # reg seri icinde mi
# Out:
# True

# %%
"a" in seri
# Out:
# False

# %%
seri["reg"]
# Out:
# 11

# %%
# fancy eleman
seri[["rf","reg"]]
# Out:
# rf     44
# reg    11
# dtype: int64

# %%
seri["reg"]
# Out:
# 11

# %%
seri["reg":"log"]
# Out:
# reg    11
# log    22
# dtype: int64
