# %% [markdown]
# # Bonus : problem Çözme ve Dokuman Okuma Kültürü

# %%
9/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 9/0
#
# ZeroDivisionError: division by zero

# %%
# hata sonunda hatanın özeti yazar. hata sonu hatayı kopyala google kopyala stack overflow da ara
# Bu sekilde benzer hataları cozebiliriz

# %% [markdown]
# # Dokuman okuma kulturu

# %%
# ilgili dokumantasyon kaynagıı okumamız gerekiyor

# %%
# google pandas documentation yazıp okumak lazım.
# ihtiyac olan bilgilere erisebiliriz
